# %%
import pandas as pd
greendale = pd.read_csv("data/greendale_students.csv")
city = pd.read_csv("data/city_college_students.csv")

# %%
greendale
# Out:
#       student  humanities_gpa  socialsci_gpa  mathsci_gpa
# 0     Jeff W.            3.04           3.23         2.30
# 1   Britta P.            3.07           3.69         3.98
# 2     Abed N.            3.38           2.80         2.57
# 3  Shirley B.            2.07           2.20         3.64
# 4    Annie E.            3.88           2.21         1.93
# 5     Troy B.            2.69           2.94         3.23
# 6   Pierce H.            3.32           3.48         3.13
# 7  Leonard R.            3.93           2.20         2.44
# 8  Garrett L.            2.76           2.84         3.54
# 9    Vicki J.            3.26           1.21         3.59

# %%
city
# Out:
#      student  humanities_gpa  socialsci_gpa  mathsci_gpa
# 0    Maya T.            3.86           2.67         3.84
# 1    Owen D.            3.13           1.88         2.69
# 2   Priya S.            3.85           3.71         3.93
# 3    Ravi K.            3.53           2.66         3.76
# 4   Tessa M.            3.72           2.96         2.66
# 5    Nora F.            2.71           1.39         3.55
# 6  Marcus B.            2.54           3.70         3.06
# 7    Ines V.            1.76           3.42         3.23
# 8   Felix A.            3.69           2.13         3.10
# 9   Delia R.            1.56           2.58         1.58

# %%
greendale_mathsci = list(greendale["mathsci_gpa"])
city_humanities = list(city["humanities_gpa"])

# %%
print(sum(greendale_mathsci))
print(sum(city_humanities))
# Out:
# 30.349999999999998
# 30.35

# %%
print(sum(greendale_mathsci)/10)
print(sum(city_humanities)/10)

# both totals are 30.35 by hand but == says False (floating pt addition errors)
# Out:
# 3.0349999999999997
# 3.035
