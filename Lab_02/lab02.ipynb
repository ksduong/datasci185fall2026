# %% [markdown]
# # lab 02: pandas vs polars; matplotlib vs seaborn
#
# <font size = "2">
# sept 04 2026

# %% [markdown]
# -  `polars` is a "high-performance" alternative to `pandas` (it can be faster than `pandas` for large data sets)
# - `seaborn` is a visualization library that is based on `matplotlib`. It makes plots/figures that are more visually pleasing.

# %%
import pandas as pd
import polars as pl
import matplotlib.pyplot as ply
import seaborn as sns

# %%
df = pd.read_csv("data/student_data.csv")
df
# Out:
#     name    major  year  study_hours  exam_score  attendance
# 0    Ava       CS     1            5          82          90
# 1    Ben  Biology     2            3          74          80
# 2    Cam       CS     3            8          94          98
# 3   Dani     Math     2            6          88          92
# 4    Eli  Biology     4            2          68          75
# 5  Faith       CS     1            7          91          95
# 6   Gabe     Math     3            4          79          84
# 7   Hope  Biology     4            5          85          89
# 8   Ivan       CS     2            9          97          99
# 9   Jada     Math     3            6          90          93
